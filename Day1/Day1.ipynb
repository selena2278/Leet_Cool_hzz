# %% [markdown]
# Day 1 Array01
#
#
# 1. Array indices always start at 0
# 2. Arrays are stored in contiguous memory locations, which means that adding or
# removing elements typically requires shifting the positions of other elements
# within the memory.

# %%
a=1
b=3
a+b
# Out:
# 4
